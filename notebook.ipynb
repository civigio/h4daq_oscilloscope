# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('csvs/csv_00000.csv')
data_x = df['Time (s)']
data_y = df['Voltage (V)']

# %%
limit = 550
plt.plot(data_x[0:limit], data_y[0:limit])
